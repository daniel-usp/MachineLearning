# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-usp/MachineLearning/blob/main/Exemplo_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = pd.read_excel("/content/varejo1.xlsx")
dataset
# Out:
#      pagamento  solteiro  idade  mulher
# 0            1         0     20       0
# 1            1         0     34       1
# 2            1         0     21       1
# 3            1         0     22       1
# 4            1         0     22       1
# ..         ...       ...    ...     ...
# 175          0         1     20       0
# 176          0         1     23       0
# 177          0         1     18       0
# 178          0         0     24       1
# 179          0         0     18       0
#
# [180 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Dados de exemplo - substitua pelos seus dados
data = pd.read_excel("/content/varejo1.xlsx")

# Criar DataFrame
df = pd.DataFrame(data)

# Definir variáveis X e Y
X = df[['idade', 'solteiro', 'mulher']]
Y = df['pagamento']

# Separar amostra em treino e teste
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Lista de k valores para testar
k_values = [1, 3, 5, 7, 9, 11]

# Variáveis para armazenar a melhor acurácia e o melhor k
best_accuracy = 0
best_k = 0

# Testar cada valor de k
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, Y_train)
    Y_pred = knn.predict(X_test)
    accuracy = accuracy_score(Y_test, Y_pred)
    print(f"Acurácia para k={k}: {accuracy:.2f}")

    # Atualizar melhor acurácia e k se necessário
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_k = k

# Estruturar o modelo final com o melhor k
final_model = KNeighborsClassifier(n_neighbors=best_k)
final_model.fit(X_train, Y_train)

# Avaliar a acurácia fora da amostra
final_Y_pred = final_model.predict(X_test)
final_accuracy = accuracy_score(Y_test, final_Y_pred)

print(f"Melhor k: {best_k}")
print(f"Acurácia fora da amostra com k={best_k}: {final_accuracy:.2f}")
# Out:
# Acurácia para k=1: 0.83
# Acurácia para k=3: 0.72
# Acurácia para k=5: 0.75
# Acurácia para k=7: 0.75
# Acurácia para k=9: 0.78
# Acurácia para k=11: 0.72
# Melhor k: 1
# Acurácia fora da amostra com k=1: 0.83
